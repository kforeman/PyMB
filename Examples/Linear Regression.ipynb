# %% [markdown]
# # PyMB Example

# %% [markdown]
# ### Import Module

# %%
import sys
sys.path.append('../..')
import PyMB

# %% [markdown]
# ### Create a new model

# %%
m = PyMB.model(name='linreg')

# %% [markdown]
# ### Define the model

# %% [markdown]
# $$ Y \sim \mathcal{N}(\hat{Y},\sigma) $$
# $$ \hat{Y} = \alpha + B x $$

# %% [markdown]
# Based on [https://github.com/kaskr/adcomp/blob/master/tmb_examples/linreg.cpp](https://github.com/kaskr/adcomp/blob/master/tmb_examples/linreg.cpp)

# %% [markdown]
# See [the TMB tutorial](https://github.com/kaskr/adcomp/wiki/Tutorial#writing-the-c-function) for more information on writing custom models

# %%
linreg_code = '''
#include <TMB.hpp>
template<class Type>
Type objective_function<Type>::operator() (){
// DATA
  DATA_VECTOR(Y);
  DATA_VECTOR(x);

// PARAMETERS
  PARAMETER(alpha);
  PARAMETER(Beta);
  PARAMETER(logSigma);

// MODEL
  vector<Type> Y_hat = alpha + Beta*x;
  REPORT(Y_hat);
  Type nll = -sum(dnorm(Y, Y_hat, exp(logSigma), true));
  return nll;
}
'''

# %% [markdown]
# ### Compile

# %% [markdown]
# See additional compiler options such as setting the R and TMB library directories via `help(PyMB.model.compile)`

# %%
m.compile(codestr=linreg_code)
# Out:
# Using tmb_tmp/linreg.cpp.
# Compiled in 24.3s.

# %% [markdown]
# ### Simulate data

# %%
import numpy as np
m.data['x'] = np.arange(10)
m.data['Y'] = m.data['x'] + 0.5 + np.random.rand(10)

# %% [markdown]
# ### Set initial parameter values

# %%
m.init['alpha'] = 0.
m.init['Beta'] = 0.
m.init['logSigma'] = 0.

# %% [markdown]
# ### Set random parameters

# %% [markdown]
# The model likelihood will be integrated wrt the random parameters. See [here](https://github.com/kaskr/adcomp/wiki/Tutorial#integrated-likelihood) for more information.

# %%
m.random = ['alpha', 'Beta']

# %% [markdown]
# ### Fit the model

# %%
m.optimize()
# Out:
# iter: 1  value: 9.51526 mgc: 323.2648 ustep: 1
# iter: 2  mgc: 7.727152e-14
# iter: 1  mgc: 7.727152e-14
# Matching hessian patterns... Done
# outer mgc:  7.348252
# iter: 1  mgc: 5.697665e-13
# iter: 1  mgc: 1.30882e-11
# iter: 1  mgc: 5.697665e-13
# outer mgc:  3.184195
# iter: 1  mgc: 2.648548e-12
# iter: 1  mgc: 8.286705e-13
# iter: 1  mgc: 8.286705e-13
# outer mgc:  1.023051
# iter: 1  mgc: 9.814372e-13
# iter: 1  mgc: 9.814372e-13
# outer mgc:  0.3153167
# iter: 1  mgc: 9.476864e-13
# iter: 1  mgc: 9.476864e-13
# outer mgc:  0.02146583
# iter: 1  mgc: 9.494627e-13
# iter: 1  mgc: 9.494627e-13
# outer mgc:  0.0004129621
# iter: 1  mgc: 9.432455e-13
# iter: 1  mgc: 9.432455e-13
# outer mgc:  5.550482e-07
# iter: 1  mgc: 9.450218e-13
# iter: 1  mgc: 9.450218e-13
# outer mgc:  1.432721e-11
# iter: 1  mgc: 9.450218e-13
#
# Model optimization complete in 0.1s.
#
#
# --------------------------------------------------------------------------------
#
# iter: 1  mgc: 9.450218e-13
# outer mgc:  1.432721e-11
# iter: 1  mgc: 9.547918e-13
# outer mgc:  0.01598401
# iter:
#  1  mgc: 9.565682e-13
# outer mgc:  0.01601601
#
# Simulated 100 draws in 0.1s.
# alpha:
# 	mean	[[ 1.20068193]]
# 	sd	[[ 0.16776078]]
# 	draws	[[ 1.23899447  1.19551035 ...,  1.17680341  1.20696336]]
# 	shape	(1, 100)
# Beta:
# 	mean	[[ 0.94468122]]
# 	sd	[[ 0.03142447]]
# 	draws	[[ 0.93851743  0.94569933 ...,  0.94832008  0.94384314]]
# 	shape	(1, 100)
# logSigma:
# 	mean	[[-1.25376915]]
# 	sd	[[ 0.24999992]]
# 	draws	[[-1.15824741 -1.32628128 ..., -1.28785579 -1.15096579]]
# 	shape	(1, 100)

# %% [markdown]
# ### Extract fitted values

# %%
print(m.report('Y_hat'))
# Out:
# [ 1.20068193  2.14536315  3.09004437  4.03472559  4.97940681  5.92408802
#   6.86876924  7.81345046  8.75813168  9.7028129 ]

# %% [markdown]
# ### Examine joint density

# %%
# %matplotlib inline
import seaborn as sns
import pandas as pd
df = pd.DataFrame({ k: v['draws'][0] for k,v in m.parameters.iteritems() })
g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap='Blues_d')
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3)
# Out:
# /usr/bin/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:476: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
